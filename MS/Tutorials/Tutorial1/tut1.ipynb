# %%
from PIL import Image, ImageDraw

# %%
inputImage=Image.open("lena.gif")
inputImage.show()

# %%
width,height=inputImage.size
print("image width =",width)
print("image height =",height)
# Out:
# image width = 512
# image height = 512

# %%
pixel_val=list(inputImage.getdata())
pixel_val
# Out:
# [172,
#  172,
#  29,
#  172,
#  172,
#  229,
#  172,
#  172,
#  29,
#  172,
#  172,
#  172,
#  43,
#  172,
#  172,
#  231,
#  231,
#  231,
#  172,
#  35,
#  43,
#  176,
#  96,
#  231,
#  140,
#  231,
#  43,
#  238,
#  178,
#  231,
#  178,
#  176,
#  94,
#  176,
#  94,
#  172,
#  231,
#  82,
#  175,
#  172,
#  171,
#  173,
#  171,
#  82,
#  82,
#  212,
#  30,
#  82,
#  30,
#  83,
#  171,
#  30,
#  171,
#  173,
#  173,
#  172,
#  100,
#  45,
#  225,
#  186,
#  53,
#  224,
#  139,
#  174,
#  63,
#  252,
#  50,
#  148,
#  148,
#  33,
#  174,
#  252,
#  243,
#  174,
#  168,
#  174,
#  174,
#  63,
#  63,
#  46,
#  168,
#  7,
#  46,
#  7,
#  7,
#  168,
#  168,
#  46,
#  46,
#  46,
#  46,
#  7,
#  46,
#  46,
#  7,
#  46,
#  46,
#  1,
#  46,
#  243,
#  202,
#  243,
#  7,
#  1,
#  1,
#  1,
#  64,
#  1,
#  1,
#  230,
#  230,
#  230,
#  55,
#  6,
#  210,
#  64,
#  3,
#  210,
#  9,
#  210,
#  61,
#  3,
#  0,
#  6,
#  210,
#  6,
#  0,
#  0,
#  0,
#  58,
#  51,
#  0,
#  3,
#  53,
#  53,
#  3,
#  250,
#  147,
#  0,
#  0,
#  194,
#  0,
#  0,
#  0,
#  53,
#  19,
#  0,
#  3,
#  0,
#  0,
#  3,
#  0,
#  122,
#  53,
#  3,
#  3,
#  53,
#  51,
#  250,
#  0,
#  3,
#  51,
#  58,
#  0,
#  0,
#  0,
#  51,
#  51,
#  194,
#  51,
#  54,
#  51,
#  51,
#  0,
#  0,
#  51,
#  51,
#  0,
#  53,
#  51,
#  194,
#  0,
#  0,
#  194,
#  0,
#  51,
#  147,
#  53,
#  0,
#  0,
#  0,
#  0,
#  0,
#  51,
#  0,
#  51,
#  51,
#  247,
#  194,
#  48,
#  51,
#  51,
#  53,
#  51,
#  51,
#  51,
#  0,
#  250,
#  99,
#  0,
#  0,
#  246,
#  53,
#  0,
#  3,
#  0,
#  53,
#  3,
#  0,
#  0,
#  147,
#  194,
#  3,
#  53,
#  53,
#  0,
#  246,
#  53,
#  147,
#  53,
#  53,
#  194,
#  53,
#  51,
#  194,
#  53,
#  58,
#  58,
#  194,
#  0,
#  51,
#  51,
#  0,
#  51,
#  194,
#  51,
#  51,
#  51,
#  0,
#  194,
#  0,
#  0,
#  0,
#  58,
#  53,
#  186,
#  186,
#  186,
#  51,
#  0,
#  0,
#  3,
#  3,
#  53,
#  0,
#  0,
#  3,
#  0,
#  53,
#  53,
#  194,
#  3,
#  0,
#  3,
#  0,
#  0,
#  198,
#  53,
#  51,
#  53,
#  0,
#  198,
#  3,
#  0,
#  3,
#  53,
#  53,
#  6,
#  3,
#  53,
#  0,
#  0,
#  53,
#  3,
#  0,
#  198,
#  3,
#  53,
#  6,
#  3,
#  3,
#  53,
#  3,
#  4,
#  9,
#  64,
#  107,
#  224,
#  224,
#  4,
#  64,
#  9,
#  139,
#  180,
#  168,
#  180,
#  180,
#  7,
#  202,
#  174,
#  7,
#  1,
#  139,
#  160,
#  210,
#  0,
#  51,
#  48,
#  48,
#  240,
#  240,
#  45,
#  178,
#  140,
#  140,
#  38,
#  231,
#  175,
#  35,
#  175,
#  226,
#  38,
#  45,
#  178,
#  96,
#  45,
#  45,
#  140,
#  45,
#  45,
#  43,
#  231,
#  96,
#  178,
#  178,
#  45,
#  178,
#  43,
#  231,
#  231,
#  172,
#  35,
#  176,
#  178,
#  45,
#  94,
#  96,
#  231,
#  140,
#  45,
#  140,
#  238,
#  94,
#  140,
#  96,
#  45,
#  43,
#  96,
#  43,
#  175,
#  45,
#  96,
#  238,
#  45,
#  238,
#  231,
#  45,
#  231,
#  175,
#  231,
#  45,
#  140,
#  231,
#  175,
#  231,
#  231,
#  178,
#  231,
#  231,
#  238,
#  178,
#  45,
#  176,
#  80,
#  234,
#  234,
#  90,
#  133,
#  133,
#  133,
#  133,
#  25,
#  25,
#  25,
#  25,
#  25,
#  25,
#  25,
#  133,
#  90,
#  234,
#  79,
#  235,
#  4,
#  168,
#  168,
#  243,
#  174,
#  243,
#  168,
#  174,
#  180,
#  180,
#  180,
#  64,
#  64,
#  9,
#  139,
#  64,
#  64,
#  4,
#  64,
#  160,
#  9,
#  64,
#  4,
#  64,
#  64,
#  64,
#  4,
#  4,
#  4,
#  64,
#  9,
#  107,
#  180,
#  64,
#  6,
#  64,
#  230,
#  64,
#  210,
#  64,
#  210,
#  4,
#  6,
#  53,
#  230,
#  6,
#  4,
#  4,
#  4,
#  3,
#  53,
#  4,
#  64,
#  6,
#  6,
#  230,
#  139,
#  3,
#  4,
#  4,
#  3,
#  198,
#  53,
#  64,
#  4,
#  3,
#  6,
#  53,
#  4,
#  3,
#  4,
#  230,
#  64,
#  139,
#  64,
#  230,
#  9,
#  230,
#  180,
#  4,
#  6,
#  247,
#  29,
#  82,
#  82,
#  82,
#  82,
#  140,
#  3,
#  172,
#  172,
#  29,
#  172,
#  172,
#  229,
#  172,
#  172,
#  29,
#  172,
#  172,
#  172,
#  43,
#  172,
#  172,
#  231,
#  231,
#  231,
#  172,
#  35,
#  43,
#  176,
#  96,
#  231,
#  140,
#  231,
#  43,
#  238,
#  178,
#  231,
#  178,
#  176,
#  94,
#  176,
#  94,
#  172,
#  231,
#  82,
#  175,
#  172,
#  171,
#  173,
#  171,
#  82,
#  82,
#  212,
#  30,
#  82,
#  30,
#  83,
#  171,
#  30,
#  171,
#  173,
#  173,
#  172,
#  100,
#  45,
#  225,
#  186,
#  53,
#  224,
#  139,
#  174,
#  63,
#  252,
#  50,
#  148,
#  148,
#  33,
#  174,
#  252,
#  243,
#  174,
#  168,
#  174,
#  174,
#  63,
#  63,
#  46,
#  168,
#  7,
#  46,
#  7,
#  7,
#  168,
#  168,
#  46,
#  46,
#  46,
#  46,
#  7,
#  46,
#  46,
#  7,
#  46,
#  46,
#  1,
#  46,
#  243,
#  202,
#  243,
#  7,
#  1,
#  1,
#  1,
#  64,
#  1,
#  1,
#  230,
#  230,
#  230,
#  55,
#  6,
#  210,
#  64,
#  3,
#  210,
#  9,
#  210,
#  61,
#  3,
#  0,
#  6,
#  210,
#  6,
#  0,
#  0,
#  0,
#  58,
#  51,
#  0,
#  3,
#  53,
#  53,
#  3,
#  250,
#  147,
#  0,
#  0,
#  194,
#  0,
#  0,
#  0,
#  53,
#  19,
#  0,
#  3,
#  0,
#  0,
#  3,
#  0,
#  122,
#  53,
#  3,
#  3,
#  53,
#  51,
#  250,
#  0,
#  3,
#  51,
#  58,
#  0,
#  0,
#  0,
#  51,
#  51,
#  194,
#  51,
#  54,
#  51,
#  51,
#  0,
#  0,
#  51,
#  51,
#  0,
#  53,
#  51,
#  194,
#  0,
#  0,
#  194,
#  0,
#  51,
#  147,
#  53,
#  0,
#  0,
#  0,
#  0,
#  0,
#  51,
#  0,
#  51,
#  51,
#  247,
#  194,
#  48,
#  51,
#  51,
#  53,
#  51,
#  51,
#  51,
#  0,
#  250,
#  99,
#  0,
#  0,
#  246,
#  53,
#  0,
#  3,
#  0,
#  53,
#  3,
#  0,
#  0,
#  147,
#  194,
#  3,
#  53,
#  53,
#  0,
#  246,
#  53,
#  147,
#  53,
#  53,
#  194,
#  53,
#  51,
#  194,
#  53,
#  58,
#  58,
#  194,
#  0,
#  51,
#  51,
#  0,
#  51,
#  194,
#  51,
#  51,
#  51,
#  0,
#  194,
#  0,
#  0,
#  0,
#  58,
#  53,
#  186,
#  186,
#  186,
#  51,
#  0,
#  0,
#  3,
#  3,
#  53,
#  0,
#  0,
#  3,
#  0,
#  53,
#  53,
#  194,
#  3,
#  0,
#  3,
#  0,
#  0,
#  198,
#  53,
#  51,
#  53,
#  0,
#  198,
#  3,
#  0,
#  3,
#  53,
#  53,
#  6,
#  3,
#  53,
#  0,
#  0,
#  53,
#  3,
#  0,
#  198,
#  3,
#  53,
#  6,
#  3,
#  3,
#  53,
#  3,
#  4,
#  9,
#  64,
#  107,
#  224,
#  224,
#  4,
#  64,
#  9,
#  139,
#  180,
#  168,
#  180,
#  180,
#  7,
#  202,
#  174,
#  7,
#  1,
#  139,
#  160,
#  210,
#  0,
#  51,
#  48,
#  48,
#  240,
#  240,
#  45,
#  178,
#  140,
#  140,
#  38,
#  231,
#  175,
#  35,
#  175,
#  226,
#  38,
#  45,
#  178,
#  96,
#  45,
#  45,
#  140,
#  45,
#  45,
#  43,
#  231,
#  96,
#  178,
#  178,
#  45,
#  178,
#  43,
#  231,
#  231,
#  172,
#  35,
#  176,
#  178,
#  45,
#  94,
#  96,
#  231,
#  140,
#  45,
#  140,
#  238,
#  94,
#  140,
#  96,
#  45,
#  43,
#  96,
#  43,
#  175,
#  45,
#  96,
#  238,
#  45,
#  238,
#  231,
#  45,
#  231,
#  175,
#  231,
#  45,
#  140,
#  231,
#  175,
#  231,
#  231,
#  178,
#  231,
#  231,
#  238,
#  178,
#  45,
#  176,
#  80,
#  234,
#  234,
#  90,
#  133,
#  133,
#  133,
#  133,
#  25,
#  25,
#  25,
#  25,
#  25,
#  25,
#  25,
#  133,
#  90,
#  234,
#  79,
#  235,
#  4,
#  168,
#  168,
#  243,
#  174,
#  243,
#  168,
#  174,
#  180,
#  180,
#  180,
#  64,
#  64,
#  9,
#  139,
#  64,
#  64,
#  4,
#  64,
#  160,
#  9,
#  64,
#  4,
#  64,
#  64,
#  64,
#  4,
#  4,
#  4,
#  64,
#  9,
#  107,
#  180,
#  64,
#  6,
#  64,
#  230,
#  64,
#  210,
#  64,
#  210,
#  4,
#  6,
#  53,
#  230,
#  6,
#  4,
#  4,
#  4,
#  3,
#  53,
#  4,
#  64,
#  6,
#  6,
#  230,
#  139,
#  3,
#  4,
#  4,
#  3,
#  198,
#  53,
#  64,
#  4,
#  ...]

# %%
import numpy as np
pixels=np.array(inputImage.getdata()).reshape(width,height,3)
print(pixels[0,2])
print(pixel_val[1])
coordinate=x,y=1,1
print(inputImage.getpixel(coordinate))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\aniru\Documents\SEM6\MS\Tutorials\tut1.ipynb Cell 5' in <module>
#       <a href='vscode-notebook-cell:/c%3A/Users/aniru/Documents/SEM6/MS/Tutorials/tut1.ipynb#ch0000004?line=0'>1</a> import numpy as np
# ----> <a href='vscode-notebook-cell:/c%3A/Users/aniru/Documents/SEM6/MS/Tutorials/tut1.ipynb#ch0000004?line=1'>2</a> pixels=np.array(inputImage.getdata()).reshape(width,height,3)
#       <a href='vscode-notebook-cell:/c%3A/Users/aniru/Documents/SEM6/MS/Tutorials/tut1.ipynb#ch0000004?line=2'>3</a> print(pixels[0,2])
#       <a href='vscode-notebook-cell:/c%3A/Users/aniru/Documents/SEM6/MS/Tutorials/tut1.ipynb#ch0000004?line=3'>4</a> print(pixel_val[1])
#
# ValueError: cannot reshape array of size 262144 into shape (512,512,3)

# %%
from PIL import Image
import numpy as np
inputImage=Image.open("lena_colour.jfif")
#inputImage.show()

width,height=inputImage.size
print("image width=",width)
print("image height=",height)

pixel_val=list(inputImage.getdata())

pixels=np.array(inputImage.getdata()).reshape(width,height,3)
print(pixels[0,2])
print(pixel_val[1])
coordinate=x, y=1,1
print(inputImage.getpixel(coordinate))
# Out:
# image width= 225
# image height= 225
# [221 133 119]
# (220, 134, 121)
# (220, 134, 121)

# %%
im_gray=inputImage.convert('L')
im_gray.show()
print(im_gray.getpixel(coordinate))
# Out:
# 158

# %%
im_cmyk=inputImage.convert('CMYK')
im_cmyk.show()
print(im_cmyk.getpixel(coordinate))
# Out:
# (35, 121, 134, 0)

# %%
from PIL import ImageDraw
for i in range(height):
    inputImage.putpixel((i,i),(0,0,0))

inputImage.show()

# %%
txt = "Neeraj eh thopu!"
size = (150, 50)
color = (255, 100, 0)
img = Image.new('RGB', size, color)
imgDrawer = ImageDraw.Draw(img)
imgDrawer.text((5, 20), txt)
img.show()

# %%
txt = "Neeraj eh thopu!"
imgDrawer = ImageDraw.Draw(inputImage)
imgDrawer.text((5, 30), txt)
inputImage.show()
